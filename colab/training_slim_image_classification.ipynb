# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 58625, done.
# remote: Counting objects: 100% (351/351), done.
# remote: Compressing objects: 100% (190/190), done.
# remote: Total 58625 (delta 212), reused 291 (delta 159), pack-reused 58274
# Receiving objects: 100% (58625/58625), 573.37 MiB | 32.93 MiB/s, done.
# Resolving deltas: 100% (40685/40685), done.

# %%
# %cd models/research/
# Out:
# /content/models/research

# %%
# !git checkout 5f4d34fc
# Out:
# Checking out files: 100% (4045/4045), done.
# Note: checking out '5f4d34fc'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>
#
# HEAD is now at 5f4d34fc Add kwargs to make the benchmark class constructor forward compatible. (#6246)

# %%
# %cd slim
# Out:
# /content/models/research/slim

# %%
# !pip install .
# Out:
# Processing /content/models/research/slim
# ...
#   Created wheel for slim: filename=slim-0.1-cp37-none-any.whl size=205718 sha256=0a12a3e41cff238ac0befb654b170c7cd4f5dd8750e2441cf483e2b4f5b4f21a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tkz9acpr/wheels/c0/cb/18/e76d02033e40846187fac06f0f855c6434d52aadf580451f20
# Successfully built slim
# ...

# %%
#edit some issue for python file in path datasets/imagenet.py 
# %cd datasets/
# !sed -i 's/filename, _ = urllib.request.urlretrieve(synset_url)/#filename, _ = urllib.request.urlretrieve(synset_url)/' imagenet.py
# !sed -i 's/filename, _ = urllib.request.urlretrieve(synset_to_human_url)/#filename, _ = urllib.request.urlretrieve(synset_to_human_url)/' imagenet.py
# !sed -i 's,https://raw.githubusercontent.com/tensorflow/models/master/research/inception/inception/data/,datasets,g' imagenet.py
# !sed -i 's/s.strip() for s in open(filename).readlines()/s.strip() for s in open(synset_url).readlines()/' imagenet.py
# !sed -i 's/synset_to_human_list = open(filename).readlines()/synset_to_human_list = open(synset_to_human_url).readlines()/' imagenet.py
# %cd ..
# Out:
# /content/models/research/slim/datasets
# /content/models/research/slim

# %%
#git clone tensorflow using python API tool convert to frozen_graph
# !git clone -b r1.15 --single-branch https://github.com/tensorflow/tensorflow.git
# Out:
# Cloning into 'tensorflow'...
# remote: Enumerating objects: 658383, done.
# remote: Counting objects: 100% (104/104), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 658383 (delta 90), reused 90 (delta 88), pack-reused 658279
# Receiving objects: 100% (658383/658383), 370.98 MiB | 25.73 MiB/s, done.
# Resolving deltas: 100% (532745/532745), done.
# Checking out files: 100% (20043/20043), done.

# %%
#vgg checkpoint form slim mdoel 
# !wget http://download.tensorflow.org/models/vgg_19_2016_08_28.tar.gz -q --show-progress --no-clobber
# !tar -xvf vgg_19_2016_08_28.tar.gz
# Out:
# vgg_19_2016_08_28.t 100%[===================>] 508.39M   216MB/s    in 2.4s
# vgg_19.ckpt

# %%
#connect with google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#set a path to google drive like: /mydrive
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
#  Arduino			'Phanit Sok.docx'
#  Cloude				'Pi4 server MQTT Broker Command line Pub-Sub'
# 'Colab Notebooks'		'Project my youtube '
#  dataset.zip			'pyboard '
#  facebookChatIoT		 python
#  Firebase			'Teensy with Arduino IDE'
# 'Line with Python Pi4'		'Telegram with pi4 esp8266-esp32'
# 'My Drive'			'ThethingIO Cloude'
#  openCV4.1.1			'ThingsboardIO cloud'
# 'บริษัท เซอร์โวเทค จำกัด-.pdf'	'Ubidots IoT platforms '
#  Phanit_Sok_116110205036-5.pdf

# %%
#make a unzip in your google drive
# !unzip /mydrive/dataset.zip -d /mydrive
# Out:
# Archive:  /mydrive/dataset.zip
#    creating: /mydrive/dataset/
#   inflating: /mydrive/dataset/flowers_train_00000-of-00004.tfrecord
#   inflating: /mydrive/dataset/flowers_train_00001-of-00004.tfrecord
#   inflating: /mydrive/dataset/flowers_train_00002-of-00004.tfrecord
#   inflating: /mydrive/dataset/flowers_train_00003-of-00004.tfrecord
#   inflating: /mydrive/dataset/flowers_validation_00000-of-00004.tfrecord
#   inflating: /mydrive/dataset/flowers_validation_00001-of-00004.tfrecord
#   inflating: /mydrive/dataset/flowers_validation_00002-of-00004.tfrecord
#   inflating: /mydrive/dataset/flowers_validation_00003-of-00004.tfrecord
#   inflating: /mydrive/dataset/labels.txt

# %%
#uncomment below for Fine-tune only the new layers for 3000 steps
# !python train_image_classifier.py --train_dir /mydrive/output_training --dataset_name flowers --dataset_split_name train --dataset_dir /mydrive/dataset/ --model_name vgg_19 --checkpoint_path vgg_19.ckpt --checkpoint_exclude_scopes=vgg_19/fc8 --trainable_scopes=vgg_19/fc8 --max_number_of_steps=3000 --batch_size 32 --save_interval_secs=60 --save_summaries_secs=60 --log_every_n_steps=100 --learning_rate=0.001 

#uncomment below for Fine-tune all the new layers for 1000 steps.
#!python train_image_classifier.py --train_dir /mydrive/output_training --dataset_name flowers --dataset_split_name train --dataset_dir /mydrive/dataset/ --model_name vgg_19 --checkpoint_path vgg_19.ckpt --max_number_of_steps=3000 --batch_size 32 --save_interval_secs=60 --save_summaries_secs=60 --log_every_n_steps=100 --learning_rate=0.001 

#if you got out of memory just set a low batch size like : 16 8 4
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/models/research/slim/nets/inception_resnet_v2.py:373: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/models/research/slim/nets/mobilenet/mobilenet.py:389: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From train_image_classifier.py:590: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# ...

# %%
# !python eval_image_classifier.py --batch_size 32 --checkpoint_path /mydrive/output_training/ --dataset_dir /mydrive/dataset/ --dataset_name flowers --dataset_split_name validation --eval_dir /mydrive/output_training/eval/ --model_name vgg_19
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/models/research/slim/nets/inception_resnet_v2.py:373: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/models/research/slim/nets/mobilenet/mobilenet.py:389: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From eval_image_classifier.py:197: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# ...

# %%
# !python export_inference_graph.py --dataset_dir /mydrive/dataset/ --dataset_name flowers --model_name vgg_19 --output_file /mydrive/output_training/vgg_19_inf_graph.pb
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/models/research/slim/nets/inception_resnet_v2.py:373: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/models/research/slim/nets/mobilenet/mobilenet.py:389: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From export_inference_graph.py:156: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# ...

# %%
#convert to freeze_graph 
# !python tensorflow/tensorflow/python/tools/freeze_graph.py --input_graph /mydrive/output_training/vgg_19_inf_graph.pb --input_checkpoint /mydrive/output_training/model.ckpt-3000 --output_graph /mydrive/output_training/vgg19.pb --input_binary true --output_node_names vgg_19/fc8/squeezed
# Out:
# WARNING:tensorflow:From tensorflow/tensorflow/python/tools/freeze_graph.py:127: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# W0710 09:56:55.221466 139944236173184 deprecation.py:323] From tensorflow/tensorflow/python/tools/freeze_graph.py:127: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# 2021-07-10 09:56:55.266860: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# ...

# %%
def download(path):
  from google.colab import files
  files.download(path)
download("/mydrive/output_training/vgg19.pb")
download("/mydrive/dataset/labels.txt")
#you can download tensorbaord checkpoint too on your google colab
